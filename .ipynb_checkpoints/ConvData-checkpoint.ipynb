# %%
import numpy as np
import cv2 as cv

# %%
im = cv.imread('Mask_Tank/hoankiem1_tank.png')
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-246957de2fcb> in <module>()
#       1 im = cv.imread('Mask_Tank/hoankiem1_tank.png')
# ----> 2 imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
#       3 ret, thresh = cv.threshold(imgray, 127, 255, 0)
#       4 contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cnt = contours[0]
x,y,w,h = cv.boundingRect(cnt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8913bbec05bd> in <module>
# ----> 1 cnt = contours[0]
#       2 x,y,w,h = cv.boundingRect(cnt)
#
# NameError: name 'contours' is not defined

# %%
from pandas import DataFrame
df = DataFrame(columns = ['image_names', 'class', 'xmin', 'xmax', 'ymin', 'ymax'])

# %%
for i in range(len(contours)):
    cnt = contours[i]
    x,y,w,h = cv.boundingRect(cnt)
    df = df.append({'image_names': "hoankiem8", 'class': 'tank', 'xmin' : x, 'xmax' : x + w, 'ymin' : y,'ymax': y + h}, ignore_index=True)

# %%
for i in range(169615):
    im = cv.imread('cropped_mask_tank/hoankiem_{}_tank.png'.format(i))
    imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
    ret, thresh = cv.threshold(imgray, 127, 255, 0)
    contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    for j in range(len(contours)):
        cnt = contours[j]
        x,y,w,h = cv.boundingRect(cnt)
        df = df.append({'image_names': "hoankiem_{}.jpg".format(i+1), 'class': 'tank', 'xmin' : x, 'xmax' : x + w, 'ymin' : y,'ymax': y + h}, ignore_index=True)

# %%
df
# Out:
#                image_names class xmin xmax ymin ymax
# 0         hoankiem_178.jpg  tank   40   69   31   48
# 1         hoankiem_178.jpg  tank   31   67   11   28
# 2         hoankiem_316.jpg  tank   94  100   39   61
# 3         hoankiem_317.jpg  tank    0   20   29   65
# 4         hoankiem_320.jpg  tank    3   34   14   35
# 5         hoankiem_377.jpg  tank   75  100   20   38
# 6         hoankiem_378.jpg  tank    0   11   24   39
# 7         hoankiem_487.jpg  tank   70  100    0   42
# 8         hoankiem_488.jpg  tank    0    9    0   21
# 9         hoankiem_509.jpg  tank    7   46   81  100
# 10        hoankiem_509.jpg  tank    3   59   61   79
# 11        hoankiem_616.jpg  tank   15   16    0    1
# 12        hoankiem_622.jpg  tank   55   89   73   94
# 13        hoankiem_799.jpg  tank   48   76   32   51
# 14        hoankiem_829.jpg  tank   72  100   99  100
# 15        hoankiem_829.jpg  tank   70  100   69   88
# 16        hoankiem_830.jpg  tank    0    6   99  100
# 17        hoankiem_830.jpg  tank    0   14   69   86
# 18        hoankiem_936.jpg  tank   67  100    0   17
# 19        hoankiem_937.jpg  tank    0   12    0   15
# 20       hoankiem_1023.jpg  tank   35   86   70   93
# 21       hoankiem_1023.jpg  tank   39   87   46   72
# 22       hoankiem_1475.jpg  tank   89  100   12   29
# 23       hoankiem_1476.jpg  tank    0   18   13   30
# 24       hoankiem_1576.jpg  tank   36   71   13   53
# 25       hoankiem_1658.jpg  tank   55   82   72  100
# 26       hoankiem_1696.jpg  tank   11   48   33   50
# 27       hoankiem_1696.jpg  tank   57   92    9   29
# 28       hoankiem_1765.jpg  tank   18   63   47   72
# 29       hoankiem_1765.jpg  tank   53   77    0   18
# ...                    ...   ...  ...  ...  ...  ...
# 19652  hoankiem_169264.jpg  tank    0   27    0   18
# 19653  hoankiem_169370.jpg  tank   69  100   95  100
# 19654  hoankiem_169371.jpg  tank    0    1   96  100
# 19655  hoankiem_169393.jpg  tank   28   43   91  100
# 19656  hoankiem_169399.jpg  tank   83  100   80  100
# 19657  hoankiem_169400.jpg  tank    0    6   80  100
# 19658  hoankiem_169476.jpg  tank   76  100   66  100
# 19659  hoankiem_169477.jpg  tank    0   10   66  100
# 19660  hoankiem_169477.jpg  tank   69  100    0   34
# 19661  hoankiem_169478.jpg  tank    0    1    0   34
# 19662  hoankiem_169480.jpg  tank   82  100   87  100
# 19663  hoankiem_169481.jpg  tank    0   10   87  100
# 19664  hoankiem_169491.jpg  tank   61   88    3   31
# 19665  hoankiem_169492.jpg  tank   72   89   82   96
# 19666  hoankiem_169500.jpg  tank   28   43    0    8
# 19667  hoankiem_169506.jpg  tank   83  100    0    4
# 19668  hoankiem_169507.jpg  tank    0    6    0    4
# 19669  hoankiem_169583.jpg  tank   90  100   13   38
# 19670  hoankiem_169583.jpg  tank   76  100    0    8
# 19671  hoankiem_169584.jpg  tank    0   18   13   38
# 19672  hoankiem_169584.jpg  tank    0   10    0    8
# 19673  hoankiem_169587.jpg  tank   82  100    0   13
# 19674  hoankiem_169588.jpg  tank   54   77   36   60
# 19675  hoankiem_169588.jpg  tank    0   10    0   13
# 19676  hoankiem_169597.jpg  tank   24   50   25   81
# 19677  hoankiem_169603.jpg  tank   97  100   80   97
# 19678  hoankiem_169604.jpg  tank   38   55   86  100
# 19679  hoankiem_169604.jpg  tank    0   11   80   97
# 19680  hoankiem_169604.jpg  tank   74  100   17   39
# 19681  hoankiem_169605.jpg  tank    0    3   17   39
#
# [19682 rows x 6 columns]

# %%
export_csv = df.to_csv ('dataframe.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
import pandas as pd
data = pd.DataFrame()
data['format'] = df['image_names']

# %%
for i in range(data.shape[0]):
    data['format'][i] = 'Train_image/' + data['format'][i] +'.jpg'

# %%
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(df['xmin'][i]) + ',' + str(df['ymin'][i]) + ',' + str(df['xmax'][i]) + ',' + str(df['ymax'][i]) + ',' + df['class'][i]

# %%
data.to_csv('annotate1.txt', header=None, index=None, sep=' ')

# %%
# !python train/train_frcnn.py -o simple -p annotate.txt
# Out:
# Parsing annotation files
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "train/train_frcnn.py", line 79, in <module>
#     all_imgs, classes_count, class_mapping = get_data(options.train_path)
#   File "C:\Users\HoangVD\Desktop\Chuyên \u0111\u1ec1 CN\train\keras_frcnn\simple_parser.py", line 37, in get_data
#     (rows,cols) = img.shape[:2]
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
data
# Out:
#                                                  format
# 0     Train_image/hoankiem1.jpg,4387,10948,4439,1097...
# 1     Train_image/hoankiem1.jpg,4390,10919,4447,1094...
# 2     Train_image/hoankiem1.jpg,4392,10775,4409,1081...
# 3     Train_image/hoankiem1.jpg,4219,10723,4240,1075...
# 4     Train_image/hoankiem1.jpg,4399,10722,4420,1077...
# 5     Train_image/hoankiem1.jpg,4408,10679,4429,1071...
# 6     Train_image/hoankiem1.jpg,7124,10633,7153,1065...
# 7     Train_image/hoankiem1.jpg,7146,10612,7160,1062...
# 8     Train_image/hoankiem1.jpg,4734,10141,4781,1017...
# 9     Train_image/hoankiem1.jpg,4740,10115,4786,1013...
# 10    Train_image/hoankiem1.jpg,4745,10089,4790,1011...
# 11    Train_image/hoankiem1.jpg,7728,9786,7761,9821,...
# 12    Train_image/hoankiem1.jpg,3280,9681,3297,9713,...
# 13    Train_image/hoankiem1.jpg,6569,9501,6602,9522,...
# 14    Train_image/hoankiem1.jpg,6481,9478,6530,9505,...
# 15    Train_image/hoankiem1.jpg,6436,9478,6481,9495,...
# 16    Train_image/hoankiem1.jpg,6388,9461,6437,9488,...
# 17    Train_image/hoankiem1.jpg,6337,9456,6385,9480,...
# 18    Train_image/hoankiem1.jpg,9414,9089,9451,9114,...
# 19    Train_image/hoankiem1.jpg,10624,8917,10650,894...
# 20    Train_image/hoankiem1.jpg,6642,8599,6663,8631,...
# 21    Train_image/hoankiem1.jpg,5138,8533,5167,8550,...
# 22    Train_image/hoankiem1.jpg,7719,8510,7746,8527,...
# 23    Train_image/hoankiem1.jpg,4969,8348,5008,8370,...
# 24    Train_image/hoankiem1.jpg,4692,8156,4723,8176,...
# 25    Train_image/hoankiem1.jpg,4942,8025,4987,8051,...
# 26    Train_image/hoankiem1.jpg,4947,8004,4994,8031,...
# 27    Train_image/hoankiem1.jpg,1055,7879,1089,7901,...
# 28    Train_image/hoankiem1.jpg,10047,7828,10087,786...
# 29    Train_image/hoankiem1.jpg,10058,7853,10061,785...
# ...                                                 ...
# 5667  Train_image/hoankiem14.jpg,1286,578,1309,607,tank
# 5668       Train_image/hoankiem14.jpg,4,575,35,607,tank
# 5669     Train_image/hoankiem14.jpg,76,574,126,622,tank
# 5670   Train_image/hoankiem14.jpg,983,565,1028,609,tank
# 5671  Train_image/hoankiem14.jpg,1499,522,1525,550,tank
# 5672    Train_image/hoankiem14.jpg,277,514,316,550,tank
# 5673  Train_image/hoankiem14.jpg,1027,495,1069,546,tank
# 5674    Train_image/hoankiem14.jpg,349,481,391,516,tank
# 5675  Train_image/hoankiem14.jpg,1074,448,1120,481,tank
# 5676  Train_image/hoankiem14.jpg,1420,409,1443,444,tank
# 5677    Train_image/hoankiem14.jpg,578,408,616,439,tank
# 5678   Train_image/hoankiem14.jpg,980,402,1041,466,tank
# 5679    Train_image/hoankiem14.jpg,387,402,436,452,tank
# 5680  Train_image/hoankiem14.jpg,1046,394,1088,414,tank
# 5681      Train_image/hoankiem14.jpg,16,374,47,400,tank
# 5682  Train_image/hoankiem14.jpg,1099,370,1125,398,tank
# 5683    Train_image/hoankiem14.jpg,952,366,985,400,tank
# 5684    Train_image/hoankiem14.jpg,136,329,185,359,tank
# 5685  Train_image/hoankiem14.jpg,1381,241,1435,270,tank
# 5686  Train_image/hoankiem14.jpg,1034,195,1087,223,tank
# 5687    Train_image/hoankiem14.jpg,553,193,587,242,tank
# 5688      Train_image/hoankiem14.jpg,55,159,88,190,tank
# 5689    Train_image/hoankiem14.jpg,546,126,580,154,tank
# 5690       Train_image/hoankiem14.jpg,6,117,29,144,tank
# 5691     Train_image/hoankiem14.jpg,530,81,557,117,tank
# 5692     Train_image/hoankiem14.jpg,300,77,360,131,tank
# 5693      Train_image/hoankiem14.jpg,452,49,492,77,tank
# 5694      Train_image/hoankiem14.jpg,905,33,952,74,tank
# 5695      Train_image/hoankiem14.jpg,142,15,185,48,tank
# 5696       Train_image/hoankiem14.jpg,529,1,586,57,tank
#
# [5697 rows x 1 columns]
